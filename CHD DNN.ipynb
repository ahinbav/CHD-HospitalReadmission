# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data=pd.read_csv('frmgham2.csv')

data.shape
#these lines of code import the libraries and adds a shortcut to each to call the function faster. Numpy allows us to
# work with arrays because machine learning models expect arrays as inputs. Matplotlib allows us to plot charts and
# graphs. Pandas allows us to import the dataset and create a matrix of features and the dependent variable vector.
# Out:
# (11627, 39)

# %%
data=pd.read_csv('frmgham2.csv')
#sets an easily accessible name to this command which can be called easily later on.

# %%
data.head()
#returns the first n rows to see if the right type of data is present
# Out:
#    RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0    2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 1    2448    1    209.0   52  121.0   66.0         0      0.0    NaN
# 2    6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 3    6238    2    260.0   52  105.0   69.5         0      0.0  29.43
# 4    6238    2    237.0   58  108.0   66.0         0      0.0  28.50
#
#    DIABETES  ...  CVD  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  TIMESTRK  \
# 0         0  ...    1         0    8766    6438      6438     6438      8766
# 1         0  ...    1         0    8766    6438      6438     6438      8766
# 2         0  ...    0         0    8766    8766      8766     8766      8766
# 3         0  ...    0         0    8766    8766      8766     8766      8766
# 4         0  ...    0         0    8766    8766      8766     8766      8766
#
#    TIMECVD  TIMEDTH  TIMEHYP
# 0     6438     8766     8766
# ...

# %%
data.describe()
#calculates statistical data like percentile, mean and std of the numerical values of the Series or DataFrame.
# Out:
#              RANDID           SEX       TOTCHOL           AGE         SYSBP  \
# count  1.162700e+04  11627.000000  11218.000000  11627.000000  11627.000000
# mean   5.004741e+06      1.568074    241.162418     54.792810    136.324116
# std    2.900877e+06      0.495366     45.368030      9.564299     22.798625
# min    2.448000e+03      1.000000    107.000000     32.000000     83.500000
# 25%    2.474378e+06      1.000000    210.000000     48.000000    120.000000
# 50%    5.006008e+06      2.000000    238.000000     54.000000    132.000000
# 75%    7.472730e+06      2.000000    268.000000     62.000000    149.000000
# max    9.999312e+06      2.000000    696.000000     81.000000    295.000000
#
#               DIABP      CURSMOKE       CIGPDAY           BMI      DIABETES  \
# count  11627.000000  11627.000000  11548.000000  11575.000000  11627.000000
# mean      83.037757      0.432528      8.250346     25.877349      0.045584
# ...

# %%
data.isnull().values.any()
#checks to see if there are any missing values.
# Out:
# True

# %%
data.columns
#lists out the different columns or risk factors in the data set.
# Out:
# Index(['RANDID', 'SEX', 'TOTCHOL', 'AGE', 'SYSBP', 'DIABP', 'CURSMOKE',
#        'CIGPDAY', 'BMI', 'DIABETES', 'BPMEDS', 'HEARTRTE', 'GLUCOSE', 'educ',
#        'PREVCHD', 'PREVAP', 'PREVMI', 'PREVSTRK', 'PREVHYP', 'TIME', 'PERIOD',
#        'HDLC', 'LDLC', 'DEATH', 'ANGINA', 'HOSPMI', 'MI_FCHD', 'ANYCHD',
#        'STROKE', 'CVD', 'HYPERTEN', 'TIMEAP', 'TIMEMI', 'TIMEMIFC', 'TIMECHD',
#        'TIMESTRK', 'TIMECVD', 'TIMEDTH', 'TIMEHYP'],
#       dtype='object')

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(20,20))
ax=fig.gca()
data.hist(ax=ax)
plt.show()
#provides histograms of all the risk factors and their prevalence across the dataset.
# Out:
# /opt/anaconda3/envs/ML-Bootcamp/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   """

# %%
data.head()
# Out:
#    RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0    2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 1    2448    1    209.0   52  121.0   66.0         0      0.0    NaN
# 2    6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 3    6238    2    260.0   52  105.0   69.5         0      0.0  29.43
# 4    6238    2    237.0   58  108.0   66.0         0      0.0  28.50
#
#    DIABETES  ...  CVD  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  TIMESTRK  \
# 0         0  ...    1         0    8766    6438      6438     6438      8766
# 1         0  ...    1         0    8766    6438      6438     6438      8766
# 2         0  ...    0         0    8766    8766      8766     8766      8766
# 3         0  ...    0         0    8766    8766      8766     8766      8766
# 4         0  ...    0         0    8766    8766      8766     8766      8766
#
#    TIMECVD  TIMEDTH  TIMEHYP
# 0     6438     8766     8766
# ...

# %%
y=data['CVD']
X=data.drop(['RANDID', 'PERIOD', 'DEATH', 'ANGINA', 'HOSPMI', 'MI_FCHD', 'ANYCHD', 'STROKE', 'CVD', 'HYPERTEN', 'TIMEAP', 'TIMEMI', 'TIMEMIFC', 'TIMECHD','TIMESTRK', 'TIMECVD', 'TIMEDTH', 'TIMEHYP'], axis=1, inplace=True)
#explanation sufficient

# %%
y.shape
# Out:
# (11627,)

# %%
data.shape
# Out:
# (11627, 21)

# %%
X=data

# %%
X.shape
#provides information on the x dimensions of the array
# Out:
# (11627, 21)

# %%
y.shape
#provides information on the y dimensions of the array
# Out:
# (11627,)

# %%
X.corr()
# Out:
#                SEX   TOTCHOL       AGE     SYSBP     DIABP  CURSMOKE  \
# SEX       1.000000  0.133932  0.027277  0.047839 -0.048977 -0.147843
# TOTCHOL   0.133932  1.000000  0.149406  0.150038  0.129694 -0.041675
# AGE       0.027277  0.149406  1.000000  0.389010  0.069258 -0.252655
# SYSBP     0.047839  0.150038  0.389010  1.000000  0.711641 -0.140761
# DIABP    -0.048977  0.129694  0.069258  0.711641  1.000000 -0.075925
# CURSMOKE -0.147843 -0.041675 -0.252655 -0.140761 -0.075925  1.000000
# CIGPDAY  -0.242665 -0.033533 -0.227588 -0.102771 -0.035321  0.781631
# BMI      -0.069445  0.080174  0.060310  0.274954  0.337553 -0.165225
# DIABETES -0.020045  0.003293  0.137484  0.144683  0.031810 -0.043479
# BPMEDS    0.083341  0.064465  0.201770  0.330333  0.228694 -0.086149
# HEARTRTE  0.102323  0.080246  0.024221  0.169816  0.179377  0.063204
# GLUCOSE  -0.016105 -0.002050  0.151874  0.152728  0.037638 -0.064483
# educ     -0.015056 -0.012177 -0.136154 -0.113369 -0.047587  0.008158
# ...

# %%
X.corrwith(y)
# Out:
# SEX        -0.175324
# TOTCHOL     0.076693
# AGE         0.210166
# SYSBP       0.228500
# DIABP       0.158936
# CURSMOKE    0.022913
# CIGPDAY     0.032098
# BMI         0.108594
# DIABETES    0.156171
# BPMEDS      0.113497
# HEARTRTE    0.013037
# GLUCOSE     0.113272
# educ       -0.071363
# PREVCHD     0.288455
# PREVAP      0.202142
# PREVMI      0.301679
# PREVSTRK    0.199700
# PREVHYP     0.206857
# TIME       -0.024752
# HDLC       -0.148418
# LDLC        0.049366
# dtype: float64

# %%
import matplotlib.pyplot as plt
plt.matshow(data.corr())
plt.show()

# %%
corr = data.corr()
corr.style.background_gradient(cmap='BuGn')
# Out:
# <style  type="text/css" >
# #T_e5f5d_row0_col0,#T_e5f5d_row1_col1,#T_e5f5d_row2_col2,#T_e5f5d_row3_col3,#T_e5f5d_row4_col4,#T_e5f5d_row5_col5,#T_e5f5d_row6_col6,#T_e5f5d_row7_col7,#T_e5f5d_row8_col8,#T_e5f5d_row9_col9,#T_e5f5d_row10_col10,#T_e5f5d_row11_col11,#T_e5f5d_row12_col12,#T_e5f5d_row13_col13,#T_e5f5d_row14_col14,#T_e5f5d_row15_col15,#T_e5f5d_row16_col16,#T_e5f5d_row17_col17,#T_e5f5d_row18_col18,#T_e5f5d_row19_col19,#T_e5f5d_row20_col20{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_e5f5d_row0_col1,#T_e5f5d_row1_col5,#T_e5f5d_row1_col6,#T_e5f5d_row13_col9,#T_e5f5d_row13_col20,#T_e5f5d_row14_col9,#T_e5f5d_row18_col15,#T_e5f5d_row19_col12{
#             background-color:  #dcf2f2;
#             color:  #000000;
#         }#T_e5f5d_row0_col2{
#             background-color:  #d1eeea;
#             color:  #000000;
# ...

# %%
age_x=data['AGE']

# %%
test_data=pd.concat([age_x,y],axis=1)

# %%
test_data
# Out:
#        AGE  CVD
# 0       39    1
# 1       52    1
# 2       46    0
# 3       52    0
# 4       58    0
# ...    ...  ...
# 11622   46    0
# 11623   52    0
# 11624   39    0
# 11625   46    0
# 11626   50    0
#
# [11627 rows x 2 columns]

# %%
test_data.corr()
# Out:
#           AGE       CVD
# AGE  1.000000  0.210166
# CVD  0.210166  1.000000

# %%
sns.heatmap(test_data.corr())
# Out:
# <AxesSubplot:>

# %%
selective_columns=data[['AGE','TOTCHOL','BMI','CIGPDAY','SYSBP','DIABP','GLUCOSE', 'DIABETES', 'HDLC', 'LDLC', 'PREVAP', 'PREVSTRK', 'PREVMI']]

# %%
target_data=pd.concat([selective_columns,y],axis=1)

# %%
corr=target_data.corr()

target_data.corr()
# Out:
#                AGE   TOTCHOL       BMI   CIGPDAY     SYSBP     DIABP  \
# AGE       1.000000  0.149406  0.060310 -0.227588  0.389010  0.069258
# TOTCHOL   0.149406  1.000000  0.080174 -0.033533  0.150038  0.129694
# BMI       0.060310  0.080174  1.000000 -0.102648  0.274954  0.337553
# CIGPDAY  -0.227588 -0.033533 -0.102648  1.000000 -0.102771 -0.035321
# SYSBP     0.389010  0.150038  0.274954 -0.102771  1.000000  0.711641
# DIABP     0.069258  0.129694  0.337553 -0.035321  0.711641  1.000000
# GLUCOSE   0.151874 -0.002050  0.079406 -0.064586  0.152728  0.037638
# DIABETES  0.137484  0.003293  0.090277 -0.040659  0.144683  0.031810
# HDLC     -0.010700  0.176499 -0.181759 -0.043997 -0.011681 -0.021964
# LDLC      0.010446  0.857232  0.067531 -0.005793  0.063484  0.041858
# PREVAP    0.193413  0.045508  0.050767 -0.045849  0.127068  0.043511
# PREVSTRK  0.103674  0.019876  0.029998 -0.027232  0.101225  0.062717
# PREVMI    0.114499  0.013218 -0.002213  0.002047  0.042769 -0.000569
# ...

# %%
pruned_correlation=corr[['CVD']]

# %%
plt.figure(figsize=(12,8))
sns.heatmap(pruned_correlation, cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,8))
sns.heatmap(target_data.corr(), cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
pruned_correlation.style.background_gradient(cmap='BuGn')
# Out:
# <style  type="text/css" >
# #T_0eeab_row0_col0{
#             background-color:  #b4e2d8;
#             color:  #000000;
#         }#T_0eeab_row1_col0{
#             background-color:  #d7f0ee;
#             color:  #000000;
#         }#T_0eeab_row2_col0{
#             background-color:  #d1eeea;
#             color:  #000000;
#         }#T_0eeab_row3_col0{
#             background-color:  #dff3f4;
#             color:  #000000;
#         }#T_0eeab_row4_col0{
#             background-color:  #acdfd4;
#             color:  #000000;
#         }#T_0eeab_row5_col0{
#             background-color:  #c5e9e2;
#             color:  #000000;
#         }#T_0eeab_row6_col0{
#             background-color:  #d1eee9;
#             color:  #000000;
#         }#T_0eeab_row7_col0{
#             background-color:  #c7eae3;
#             color:  #000000;
#         }#T_0eeab_row8_col0{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_0eeab_row9_col0{
# ...

# %%
import numpy as np
np.isnan(X).sum()
# Out:
# SEX            0
# TOTCHOL      409
# AGE            0
# SYSBP          0
# DIABP          0
# CURSMOKE       0
# CIGPDAY       79
# BMI           52
# DIABETES       0
# BPMEDS       593
# HEARTRTE       6
# GLUCOSE     1440
# educ         295
# PREVCHD        0
# PREVAP         0
# PREVMI         0
# PREVSTRK       0
# PREVHYP        0
# TIME           0
# HDLC        8600
# LDLC        8601
# dtype: int64

# %%
np.isnan(y).sum()
# Out:
# 0

# %%
#from sklearn.impute import SimpleImputer

#datafiller=SimpleImputer(missing_values=np.nan,strategy='median')
#X_SEX=datafiller.fit_transform(X['SEX'].values.reshape(-1,1))
#way to fill in missing values

# %%
from sklearn.impute import SimpleImputer

datafiller=SimpleImputer(missing_values=np.nan,strategy='mean')
X=datafiller.fit_transform(X)
#way to fill in missing values

# %%
np.isnan(X).sum()
# Out:
# 0

# %%
X.shape
# Out:
# (11627, 21)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,shuffle=True)

# %%
X_train.shape
#size of the training set
# Out:
# (9301, 21)

# %%
from sklearn.preprocessing import StandardScaler

sc=StandardScaler()

X=sc.fit_transform(X)

# %%
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)

# %%
X_train
# Out:
# array([[-1.14390265e+00,  9.40145168e-01, -1.33674213e+00, ...,
#         -1.10710124e+00,  7.15711680e-03,  9.42304525e-04],
#        [-1.14390265e+00, -1.74184695e+00, -2.86689889e-01, ...,
#          1.41265824e+00, -3.90585153e-02, -2.59708733e+00],
#        [ 8.74200263e-01,  1.66135313e+00,  9.73372797e-01, ...,
#         -1.10710124e+00,  7.15711680e-03,  9.42304525e-04],
#        ...,
#        [-1.14390265e+00,  2.41474953e-01, -1.81684665e-01, ...,
#          1.37683227e+00,  3.76242839e+00, -6.52800894e-01],
#        [ 8.74200263e-01, -2.77975817e-03,  1.18338324e+00, ...,
#          1.70691479e-01,  7.15711680e-03,  9.42304525e-04],
#        [-1.14390265e+00, -1.33616747e+00,  1.18338324e+00, ...,
#          1.34865515e-01,  7.15711680e-03,  9.42304525e-04]])

# %%
import keras
from keras.layers import Dropout
from keras.layers import Activation, Dense
from keras.callbacks import LearningRateScheduler
from sklearn.model_selection import KFold 
from sklearn.model_selection import RepeatedKFold
from My import MyClass
obj = MyClass();
print(obj.myVar);
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-51-9d5357c88d2d> in <module>
#       5 from sklearn.model_selection import KFold
#       6 from sklearn.model_selection import RepeatedKFold
# ----> 7 from My import MyClass
#       8 obj = MyClass();
#       9 print(obj.myVar);
#
# ModuleNotFoundError: No module named 'My'

# %%
import schedule
kf = RepeatedKFold(n_splits=5, n_repeats=10, random_state=None) 

fold_no=1
for train_index, test_index in kf.split(X,y):
    model=keras.models.Sequential()
    model.add(Dense(128,activation='relu'))
    model.add(Dense(256,activation='relu'))
    model.add(Dense(512,activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(64,activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(32,activation='relu'))
    model.add(Dense(1,activation='sigmoid'))
    
    
    optimizer=keras.optimizers.Adam(lr=0.0001)
    earlystopping=keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=5,restore_best_weights=True)
    learningrateschedule=keras.callbacks.LearningRateScheduler(schedule)
    
    print('Training for {fold_no}')

    model.compile(optimizer=optimizer,loss='binary_crossentropy',metrics=['accuracy'])
    history=model.fit(X_train,y_train,validation_data=(X_test,y_test),batch_size=64,epochs=50,callbacks=[earlystopping,learningrateschedule])

    
    scores=model.evaluate(X_test,y_test,verbose=0)
    
    print("The accuracy of the model in Fold {fold_no} is {scores}")
          
          
    fold_no+=1
#       print("Train:", train_index, "Validation:",test_index)
#       X_train, X_test = X[train_index], X[test_index] 
#       y_train, y_test = y[train_index], y[test_index]
# Out:
# Training for {fold_no}
# Epoch 1/50
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/anaconda3/envs/ML-Bootcamp/lib/python3.7/site-packages/tensorflow/python/keras/callbacks.py in on_epoch_begin(self, epoch, logs)
#    1904       lr = float(K.get_value(self.model.optimizer.lr))
# -> 1905       lr = self.schedule(epoch, lr)
#    1906     except TypeError:  # Support for old API for backward compatibility
#
# TypeError: 'module' object is not callable
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-4eb63fc652cc> in <module>
#      22
#      23     model.compile(optimizer=optimizer,loss='binary_crossentropy',metrics=['accuracy'])
# ...

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(accuracy_legend)
plt.title('Training and Validation Accuracy')
plt.xlabel("Number of Epochs")
plt.ylabel("Accuracy %")

# %%
from keras.models import Sequential
from keras.layers import Dense,Dropout
from keras.optimizers import SGD
import keras
import tensorflow

# %%
model=Sequential()
model.add(Dense(128,activation='relu'))
model.add(Dense(256,activation='relu'))
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(32,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
def schedule(epoch,lr):
    if epoch<5:
        return lr
    else:
        return lr*tensorflow.math.exp(-0.1)

optimizer=keras.optimizers.Adam(lr=0.0001)
earlystopping=keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=5,restore_best_weights=True)
learningrateschedule=keras.callbacks.LearningRateScheduler(schedule)

# %%
model.compile(optimizer=optimizer,loss='binary_crossentropy',metrics=['accuracy'])

# %%
history=model.fit(X_train,y_train,validation_data=(X_test,y_test),batch_size=64,epochs=50,callbacks=[earlystopping,learningrateschedule])
# Out:
# Epoch 1/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.6007 - accuracy: 0.6943 - val_loss: 0.4532 - val_accuracy: 0.7945
# Epoch 2/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.4563 - accuracy: 0.7933 - val_loss: 0.4426 - val_accuracy: 0.7932
# Epoch 3/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.4527 - accuracy: 0.7932 - val_loss: 0.4394 - val_accuracy: 0.7928
# Epoch 4/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.4426 - accuracy: 0.7975 - val_loss: 0.4366 - val_accuracy: 0.7941
# Epoch 5/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.4335 - accuracy: 0.8037 - val_loss: 0.4364 - val_accuracy: 0.7919
# Epoch 6/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.4323 - accuracy: 0.8042 - val_loss: 0.4354 - val_accuracy: 0.7941

# %%
history.history

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend({"Loss":1,"Validation Loss":2})
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title('Training and Validation Losses')

# %%
history.history.keys()

# %%
loss_legend={'Training_loss':123,'Validation_loss':123}
accuracy_legend={'Training_Accuracy':123,'Validation_Accuracy':123}

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(accuracy_legend)
plt.title('Training and Validation Accuracy')
plt.xlabel("Number of Epochs")
plt.ylabel("Accuracy %")

# %%
history.history

# %%
model.predict(X_test)

# %%
y_test

# %%
model.save('CHD_Prediction.h5')

# %%
X_test[0]

# %%
np.save('X_test',X_test)
np.save('X_train',X_train)
np.save('y_test',y_test)
np.save('y_train',y_train)

# %%
from keras.models import load_model

model=load_model('CHD_Prediction.h5')

# %%
import os

# %%
os.getcwd()

# %%
X_test[61]

# %%
import numpy as np

# %%
X_test=np.load('X_test.npy')

# %%
len(X_test[61])

# %%
X_test[61]

# %%
len(X_test[142])

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_train)
